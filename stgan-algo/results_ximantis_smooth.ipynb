# %% [markdown]
# # Analysis of the results for the Ximantis dataset
# ## Setup

# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# ## Results

# %%
result = torch.tensor(np.load("STGAN/ximantis_smooth/result/result.npy"), dtype=torch.float)

# %%
result.shape
# Out:
# torch.Size([1728, 42, 3])

# %%
camera_num = 19
feature_num = 0
timestamp = 12
day_length = 24 * timestamp
days = 1

# %%
pd.DataFrame(result[:days*day_length, camera_num, feature_num].numpy()).plot()
# Out:
# <Axes: >

# %%
feature_num = 1
pd.DataFrame(result[:days*day_length, camera_num, feature_num].numpy()).plot()
# Out:
# <Axes: >

# %%
feature_num = 2
pd.DataFrame(result[:days*day_length, camera_num, feature_num].numpy()).plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Anomaly score
# Combining the two scores, from the generator and the discriminator.

# %%
s_G = pd.DataFrame(result[:days*day_length, camera_num, 0].numpy())
s_D = pd.DataFrame(result[:days*day_length, camera_num, 1].numpy()) - pd.DataFrame(result[:days*day_length, camera_num, 2].numpy())

# %%
lambda_coef = 1.0
anomaly_score = s_G + lambda_coef * s_D
anomaly_score.columns = ["Score"]

# %%
anomaly_score
# Out:
#        Score
# 0   -0.00014
# 1   -0.00014
# 2   -0.00014
# 3   -0.00014
# 4   -0.00014
# ..       ...
# 283 -0.00009
# 284 -0.00009
# 285 -0.00009
# 286 -0.00009
# 287 -0.00009
#
# [288 rows x 1 columns]

# %%
anomaly_score.plot()
# Out:
# <Axes: >

# %%
anomaly_threshold = .75
anomalies = anomaly_score[anomaly_score.Score > anomaly_threshold].index
anomalies
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# ## Real data

# %%
data = torch.tensor(np.load("STGAN/ximantis_smooth/data/data.npy"), dtype=torch.float)
data.shape
# Out:
# torch.Size([5184, 42, 1, 1])

# %%
train_time = 12
df = pd.DataFrame(data[train_time*day_length:(train_time+days)*day_length, camera_num, 0, 0])
df.columns = ["Flow"]

# %%
df.plot()
# Out:
# <Axes: >

# %%
anomalies
# Out:
# Int64Index([], dtype='int64')

# %%
plt.figure(figsize=(10, 6))
plt.plot(df["Flow"])

for i, time in enumerate(anomalies):
    if i == 0:
        plt.axvline(x=time, color='r', linestyle='--', linewidth=1, alpha=0.5, label="Anomalies")
    else:
        plt.axvline(x=time, color='r', linestyle='--', linewidth=1, alpha=0.5)


plt.xlabel("Timestamps")
plt.ylabel("Flow")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Anomaly scores from all the cameras

# %%
lambda_coef = 1.0
camera_num = 0
s_G = pd.DataFrame(result[:, camera_num, 0].numpy())
s_D = pd.DataFrame(result[:, camera_num, 1].numpy()) - pd.DataFrame(result[:, camera_num, 2].numpy())
column_name = "ScoreCamera" + str(camera_num)
anomaly_score = pd.DataFrame([], columns=[column_name])
anomaly_score[column_name] = s_G + lambda_coef * s_D

# %%
camera_num = 1
s_G = pd.DataFrame(result[:, camera_num, 0].numpy())
s_D = pd.DataFrame(result[:, camera_num, 1].numpy()) - pd.DataFrame(result[:, camera_num, 2].numpy())
column_name = "ScoreCamera" + str(camera_num)
anomaly_score[column_name] = s_G + lambda_coef * s_D

# %%
anomaly_score.plot()
# Out:
# <Axes: >

# %%
lambda_coef = 1.0
for camera_num in range(result.shape[1]):
    column_name = "ScoreCamera" + str(camera_num)
    if camera_num == 0:
        anomaly_score = pd.DataFrame([], columns=[column_name])
    s_G = pd.DataFrame(result[:, camera_num, 0].numpy())
    s_D = pd.DataFrame(result[:, camera_num, 1].numpy()) - pd.DataFrame(result[:, camera_num, 2].numpy())
    anomaly_score[column_name] = s_G + lambda_coef * s_D

# %%
anomaly_score[["ScoreCamera0", "ScoreCamera10", "ScoreCamera20"]].plot()
# Out:
# <Axes: >

# %%
anomaly_score
# Out:
#       ScoreCamera0  ScoreCamera1  ScoreCamera2  ScoreCamera3  ScoreCamera4  \
# 0         -0.00014     -0.000140     -0.000140     -0.000140     -0.000140
# 1         -0.00014     -0.000141     -0.000140     -0.000140     -0.000140
# 2         -0.00014     -0.000140     -0.000140     -0.000140     -0.000140
# 3         -0.00014     -0.000140     -0.000140     -0.000141     -0.000140
# 4         -0.00014     -0.000140     -0.000141     -0.000140     -0.000140
# ...            ...           ...           ...           ...           ...
# 1723      -0.00009     -0.000090     -0.000090     -0.000090     -0.000090
# 1724      -0.00009     -0.000090     -0.000090     -0.000090     -0.000089
# 1725      -0.00009     -0.000090     -0.000089     -0.000090     -0.000090
# 1726      -0.00009     -0.000090     -0.000090     -0.000090     -0.000090
# 1727      -0.00009     -0.000089     -0.000090     -0.000090     -0.000090
#
#       ScoreCamera5  ScoreCamera6  ScoreCamera7  ScoreCamera8  ScoreCamera9  \
# 0        -0.000140     -0.000141      -0.00014      -0.00014     -0.000140
# 1        -0.000141     -0.000141      -0.00014      -0.00014     -0.000140
# 2        -0.000140     -0.000140      -0.00014      -0.00014     -0.000140
# 3        -0.000140     -0.000140      -0.00014      -0.00014     -0.000140
# 4        -0.000140     -0.000140      -0.00014      -0.00014     -0.000140
# ...            ...           ...           ...           ...           ...
# 1723     -0.000089     -0.000090      -0.00009      -0.00009     -0.000090
# 1724     -0.000090     -0.000090      -0.00009      -0.00009     -0.000090
# 1725     -0.000090     -0.000090      -0.00009      -0.00009     -0.000090
# 1726     -0.000090     -0.000090      -0.00009      -0.00009     -0.000089
# 1727     -0.000090     -0.000089      -0.00009      -0.00009     -0.000090
#
#       ...  ScoreCamera32  ScoreCamera33  ScoreCamera34  ScoreCamera35  \
# 0     ...      -0.000140       -0.00014       -0.00014      -0.000140
# 1     ...      -0.000140       -0.00014       -0.00014      -0.000141
# 2     ...      -0.000140       -0.00014       -0.00014      -0.000140
# 3     ...      -0.000140       -0.00014       -0.00014      -0.000140
# 4     ...      -0.000140       -0.00014       -0.00014      -0.000140
# ...   ...            ...            ...            ...            ...
# 1723  ...      -0.000090       -0.00009       -0.00009      -0.000090
# 1724  ...      -0.000090       -0.00009       -0.00009      -0.000089
# 1725  ...      -0.000089       -0.00009       -0.00009      -0.000090
# 1726  ...      -0.000090       -0.00009       -0.00009      -0.000089
# 1727  ...      -0.000090       -0.00009       -0.00009      -0.000089
#
#       ScoreCamera36  ScoreCamera37  ScoreCamera38  ScoreCamera39  \
# 0         -0.000140      -0.000140       -0.00014      -0.000140
# 1         -0.000140      -0.000141       -0.00014      -0.000141
# 2         -0.000141      -0.000140       -0.00014      -0.000140
# 3         -0.000141      -0.000140       -0.00014      -0.000140
# 4         -0.000140      -0.000140       -0.00014      -0.000140
# ...             ...            ...            ...            ...
# 1723      -0.000090      -0.000089       -0.00009      -0.000090
# 1724      -0.000090      -0.000089       -0.00009      -0.000090
# 1725      -0.000090      -0.000090       -0.00009      -0.000090
# 1726      -0.000089      -0.000090       -0.00009      -0.000090
# 1727      -0.000090      -0.000090       -0.00009      -0.000090
#
#       ScoreCamera40  ScoreCamera41
# 0          -0.00014      -0.000141
# 1          -0.00014      -0.000140
# 2          -0.00014      -0.000140
# 3          -0.00014      -0.000140
# 4          -0.00014      -0.000140
# ...             ...            ...
# 1723       -0.00009      -0.000090
# 1724       -0.00009      -0.000090
# 1725       -0.00009      -0.000090
# 1726       -0.00009      -0.000090
# 1727       -0.00009      -0.000090
#
# [1728 rows x 42 columns]

# %% [markdown]
# ## Selecting the top K% anomaly scores

# %%
K = 0.00004

# %%
anomaly_score_flattened = pd.Series([], dtype=float)
for i, col in enumerate(anomaly_score.columns):
    anomaly_score_flattened = pd.concat([anomaly_score_flattened, anomaly_score[col]], ignore_index=True)
anomaly_score_flattened
# Out:
# 0       -0.00014
# 1       -0.00014
# 2       -0.00014
# 3       -0.00014
# 4       -0.00014
#           ...
# 72571   -0.00009
# 72572   -0.00009
# 72573   -0.00009
# 72574   -0.00009
# 72575   -0.00009
# Length: 72576, dtype: float32

# %%
top = int(np.floor(K * len(anomaly_score_flattened)))

# %%
anomaly_score_flattened.plot()
# Out:
# <Axes: >

# %%
anomalies = anomaly_score_flattened.sort_values(ascending=False)[:top].index
anomalies
# Out:
# Int64Index([11580, 31740], dtype='int64')

# %% [markdown]
# ## Plotting the anomalies for a specific camera

# %%
camera_nums, minutes = divmod(anomalies,result.shape[0])

# %%
camera_nums
# Out:
# Int64Index([6, 18], dtype='int64')

# %%
minutes
# Out:
# Int64Index([1212, 636], dtype='int64')

# %%
# Choose the camera
camera_num = 6

# %%
minutes[camera_nums == camera_num]
# Out:
# Int64Index([1212], dtype='int64')

# %%
# Read again, all the training data
data = torch.tensor(np.load("STGAN/ximantis_smooth/data/data.npy"), dtype=torch.float)
df = pd.DataFrame(data[train_time*day_length:, camera_num, 0, 0])
df.columns = ["Flow"]

# %%
plt.figure(figsize=(10, 6))
plt.plot(df["Flow"])

for i, time in enumerate(minutes[camera_nums == camera_num]):
    if i == 0:
        plt.axvline(x=time, color='r', linestyle='--', linewidth=1, alpha=0.5, label="Anomalies")
    else:
        plt.axvline(x=time, color='r', linestyle='--', linewidth=1, alpha=0.5)


plt.xlabel("Timestamps")
plt.ylabel("Flow")
plt.ylim([0,1])
plt.legend()
plt.show()

# %% [markdown]
# ### Creating a function

# %%
def plot_anomalies(camera_num, K=0.00004, anomaly_score=anomaly_score, train_time=12):
    anomaly_score_flattened = pd.Series([], dtype=float)
    for i, col in enumerate(anomaly_score.columns):
        anomaly_score_flattened = pd.concat([anomaly_score_flattened, anomaly_score[col]], ignore_index=True)
    top = int(np.floor(K * len(anomaly_score_flattened)))
    anomalies = anomaly_score_flattened.sort_values(ascending=False)[:top].index
    camera_nums, minutes = divmod(anomalies, anomaly_score.shape[0])
    data = torch.tensor(np.load("STGAN/ximantis_smooth/data/data.npy"), dtype=torch.float)
    df = pd.DataFrame(data[train_time*day_length:, camera_num, 0, 0])
    plt.figure(figsize=(10, 6))
    plt.plot(df)

    for i, time in enumerate(minutes[camera_nums == camera_num]):
        if i == 0:
            plt.axvline(x=time, color='r', linestyle='--', linewidth=1, alpha=0.5, label="Anomalies")
        else:
            plt.axvline(x=time, color='r', linestyle='--', linewidth=1, alpha=0.5)


    plt.xlabel("Timestamps")
    plt.ylabel("Flow")
    plt.ylim([0,1])
    plt.legend()
    plt.show()

# %%
plot_anomalies(camera_num, K, anomaly_score, train_time)

# %%
plot_anomalies(camera_num=18)
